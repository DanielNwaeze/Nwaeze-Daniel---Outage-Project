# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
from pprint import pprint

# %%
import re
from bs4 import BeautifulSoup
import requests
import pandas as pd

response = requests.get('https://www.ikejaelectric.com/cnn/')
soup = BeautifulSoup(response.content, 'html.parser')

fault_entries = soup.find_all('div', class_='post')

# Lists to store the extracted information
post_categories = []
post_dates = []
undertakings = []
faults = []
areas_affected_s = []

for entry in fault_entries:
    post_category = entry.find('a', class_='post-category').text.strip()
    post_date = entry.find('span', class_='post-date').text.strip()

    # Extract information from the h3 tag
    h3_tag = entry.find('h3', class_='post-title')

    # Extract text from the h3 tag
    h3_text = h3_tag.get_text(separator='\n', strip=True)

    # Extract undertaking, fault, and areas affected using regular expressions
    undertaking_match = re.search(r'UNDERTAKING:(.*?)FAULT:', h3_text, re.DOTALL)
    fault_match = re.search(r'FAULT:(.*?)AREAS AFFECTED:', h3_text, re.DOTALL)
    areas_affected_match = re.search(r'AREAS AFFECTED:(.*?)$', h3_text, re.DOTALL)

    # Check if matches are found before extracting
    undertaking = undertaking_match.group(1).strip() if undertaking_match else "Not found"
    fault = fault_match.group(1).strip() if fault_match else "Not found"
    areas_affected = areas_affected_match.group(1).strip() if areas_affected_match else "Not found"

    # Append the extracted information to the lists
    post_categories.append(post_category)
    post_dates.append(post_date)
    undertakings.append(undertaking)
    faults.append(fault)
    areas_affected_s.append(areas_affected)

# Create a pandas DataFrame from the lists
data = {
    'Branch': post_categories,
    'Date': post_dates,
    'Undertaking': undertakings,
    'Fault': faults,
    'Areas': areas_affected_s
}

df = pd.DataFrame(data)

# %%
df = pd.DataFrame(data)
df.head(3)
# Out:
#        Branch              Date Undertaking  \
# 0     IKORODU  Thu, 04 Apr 2024         EPE
# 1     SHOMOLU  Thu, 04 Apr 2024      IGBOBI
# 2  ABULE-EGBA  Tue, 02 Apr 2024         IJU
#
#                                                Fault  \
# 0                   AGBOWA 33KV FEEDER OUT ON FAULTS
# 1  PROLONGED OUTAGE ON 33-OWORONSHOKITCN-IGBOBI F...
# 2                       OUTAGE ON ISHAGA 11KV FEEDER
#
#                              Areas
# 0               AGBOWA 33KV FEEDER
# 1  33-OWORONSHOKITCN-IGBOBI FEEDER
# 2              11-IJUINJ-T2-ISHAGA

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#          Branch       Date Undertaking  \
# 0    ABULE-EGBA 2024-03-01         IJU
# 1    ABULE-EGBA 2024-01-08         IJU
# 2    ABULE-EGBA 2024-01-08         IJU
# 3      AKOWONJO 2024-01-05         OKE
# 4    ABULE-EGBA 2023-12-23         IJU
# ..          ...        ...         ...
# 573  ABULE-EGBA 2021-10-10       FAGBA
# 574  ABULE-EGBA 2021-10-10       FAGBA
# 575  ABULE-EGBA 2021-10-04       FAGBA
# 576     SHOMOLU 2021-10-02       OWORO
# 577     SHOMOLU 2021-10-02       OWORO
#
#                                                  Fault  \
# 0    CNN NOTIFICATIONS TO CUSTOMERS ON 11-OBAWOLEIN...
# 1           CNN REQUEST TO CUSTOMERS OUT DUE TO FAULT.
# 2                           OUTAGE ON GALILEE 11KV FDR
# 3                PROLONG OUTAGE ON OKE ODO 11KV FEEDER
# 4                           OUTAGE ON GALILEE 11KV FDR
# ..                                                 ...
# 573                     FAULT ON AGBE ROAD 11KV FEEDER
# 574                     FAULT ON AGBE ROAD 11KV FEEDER
# 575  FAULT ON 11-IJAIYE OJOKOROINJ-T1-AGBADO 2-MAJE...
# 576                         FAULT ON OWORO IGBOBI 33KV
# 577                         FAULT ON OWORO IGBOBI 33KV
#
#                                                  Areas
# 0    CUSTOMERS ON 11-OBAWOLEINJ-T1-SHONUBI-CAJE 2 3...
# 1    11-AGEGEINJ-T1-IJU ROAD-1 OPA ARO CL HVDS – OP...
# 2                                         GALILEE 11KV
# 3                                              OKE ODO
# 4                                         GALILEE 11KV
# ..                                                 ...
# 573                 CUSTOMERS ON AGBE ROAD 11KV FEEDER
# 574                 CUSTOMERS ON AGBE ROAD 11KV FEEDER
# 575  CUSTOMERS ON 11-IJAIYE OJOKOROINJ-T1-AGBADO 2-...
# 576                     CUSTOMERS ON OWORO IGBOBI 33KV
# 577                     CUSTOMERS ON OWORO IGBOBI 33KV
#
# [578 rows x 5 columns]

# %%
#app = Nominatim(user_agent="project")
for index, row in df.iterrows():
    # Access row data
    branch = row['Branch']
    try:
        app = Nominatim(user_agent="project")
        location = app.geocode(branch + " Lagos").raw
    except:
        app = Nominatim(user_agent="project")
        location = app.geocode(branch).raw
    y = location['lat']
    x = location['lon']
    df.at[index, 'y'] = y
    df.at[index, 'x'] = x

# %%
df
# Out:
#          Branch       Date Undertaking  \
# 0    ABULE-EGBA 2024-03-01         IJU
# 1    ABULE-EGBA 2024-01-08         IJU
# 2    ABULE-EGBA 2024-01-08         IJU
# 3      AKOWONJO 2024-01-05         OKE
# 4    ABULE-EGBA 2023-12-23         IJU
# ..          ...        ...         ...
# 573  ABULE-EGBA 2021-10-10       FAGBA
# 574  ABULE-EGBA 2021-10-10       FAGBA
# 575  ABULE-EGBA 2021-10-04       FAGBA
# 576     SHOMOLU 2021-10-02       OWORO
# 577     SHOMOLU 2021-10-02       OWORO
#
#                                                  Fault  \
# 0    CNN NOTIFICATIONS TO CUSTOMERS ON 11-OBAWOLEIN...
# 1           CNN REQUEST TO CUSTOMERS OUT DUE TO FAULT.
# 2                           OUTAGE ON GALILEE 11KV FDR
# 3                PROLONG OUTAGE ON OKE ODO 11KV FEEDER
# 4                           OUTAGE ON GALILEE 11KV FDR
# ..                                                 ...
# 573                     FAULT ON AGBE ROAD 11KV FEEDER
# 574                     FAULT ON AGBE ROAD 11KV FEEDER
# 575  FAULT ON 11-IJAIYE OJOKOROINJ-T1-AGBADO 2-MAJE...
# 576                         FAULT ON OWORO IGBOBI 33KV
# 577                         FAULT ON OWORO IGBOBI 33KV
#
#                                                  Areas       y       x
# 0    CUSTOMERS ON 11-OBAWOLEINJ-T1-SHONUBI-CAJE 2 3...  6.6712  3.3515
# 1    11-AGEGEINJ-T1-IJU ROAD-1 OPA ARO CL HVDS – OP...  6.6712  3.3515
# 2                                         GALILEE 11KV  6.6712  3.3515
# 3                                              OKE ODO  6.6263  3.2835
# 4                                         GALILEE 11KV  6.6712  3.3515
# ..                                                 ...     ...     ...
# 573                 CUSTOMERS ON AGBE ROAD 11KV FEEDER     NaN     NaN
# 574                 CUSTOMERS ON AGBE ROAD 11KV FEEDER     NaN     NaN
# 575  CUSTOMERS ON 11-IJAIYE OJOKOROINJ-T1-AGBADO 2-...     NaN     NaN
# 576                     CUSTOMERS ON OWORO IGBOBI 33KV     NaN     NaN
# 577                     CUSTOMERS ON OWORO IGBOBI 33KV     NaN     NaN
#
# [578 rows x 7 columns]

# %%
locations = {'ABULE-EGBA':[6.6478943,3.3046224], 'AKOWONJO':[6.6104787,3.3103079],
             'IKORODU':[6.6191233,3.5041271], 'IKEJA':[6.5960605, 3.340787],
             'OSHODI':[6.5400100000000005,3.3124146026491035], 'SHOMOLU':[6.533564500000001,3.38416340600858]}

# %%
df['Undertaking'].unique()
# Out:
# array(['EPE', 'IGBOBI', 'IJU', 'ODOGUNYAN', 'DOPEMU', 'FAGBA', 'AMUWO',
#        'MAGODO', 'OKE', 'AYANGBURIN', 'OREGUN', 'EGBEDA', 'PTC', 'AIT',
#        'ABULE', 'IGANDO', 'ADIYAN', 'LASUNWON', 'IJAIYE', 'IKOTUN',
#        'OWUTU', 'IFAKO', 'OBA', 'OKEIRA', 'OLAMBE', 'AKUTE', 'KETU',
#        'MENDE', 'OJODU', 'ILUPEJU', 'OSHODI', 'ISOLO', 'ANIFOWOSHE',
#        'BARIGA', 'OLATEJU', 'IDIMU', 'AGO', 'AYOBO', 'OWORO', 'IKOSI',
#        'AJAO', 'IPAJA', 'IJEDE', 'IGBOGBO', 'OKOTA', 'GOWON-ESTATE',
#        'OLOWORA', 'OGBA', 'IJEGUN', 'OGUDU', 'ABORU', 'ORILE-AGEGE'],
#       dtype=object)

# %%
df[df['Undertaking'].str.contains('abule', case=False)].head(10)
# Out:
#        Branch       Date Undertaking  \
# 14   AKOWONJO 2023-12-02       ABULE
# 31   AKOWONJO 2023-11-13       ABULE
# 52   AKOWONJO 2023-10-04       ABULE
# 58   AKOWONJO 2023-10-03       ABULE
# 59   AKOWONJO 2023-08-31       ABULE
# 231  AKOWONJO 2022-12-29       ABULE
# 236  AKOWONJO 2022-12-24       ABULE
# 243  AKOWONJO 2022-12-21       ABULE
# 306  AKOWONJO 2022-10-07       ABULE
# 307  AKOWONJO 2022-10-06       ABULE
#
#                                                  Fault  \
# 14   CNN TO ALL CUSTOMERS FEEDING FROM ALIMOSHO 3X1...
# 31                 PROLONG OUTAGE ON EKORO 11KV FEEDER
# 52   CNN TO AFFECTED CUSTOMERS ON AKOWONJO 11KV FEEDER
# 58   BROADCAST TO CUSTOMERS UNDER 11-EKOROINJ-T2-OL...
# 59   BROADCAST TO CUSTOMERS UNDER 11-EKOROINJ-T2-OL...
# 231                   TCN BREAKER FAULT ON T8 ALIMOSHO
# 236                   TERMINATION FAILURE AT EJIGBO TX
# 243         PLANNED OUTAGE ON ABULE-TAYLOR 33KV FEEDER
# 306  PLANNED OUTAGE REQUEST ON ABULE TAYLOR 33KV FE...
# 307             EMERGENCY OUTAGE ON T2 100MVA ALIMOSHO
#
#                                                  Areas   y   x
# 14   11-ALIMOSHOINJ-T4-AKOWONJO 11-ALIMOSHOINJ-T4-F... NaN NaN
# 31                                   EKORO 11KV FEEDER NaN NaN
# 52                                AKOWONJO 11KV FEEDER NaN NaN
# 58                    11-EKOROINJ-T2-OLOTA-ISE OLUWA 1 NaN NaN
# 59                    11-EKOROINJ-T2-OLOTA-ISE OLUWA 1 NaN NaN
# 231                         ALIMOSHO, ABULE ODU, GOWON NaN NaN
# 236                   TERMINATION FAILURE AT EJIGBO TX NaN NaN
# 243                           ABULE-TAYLOR 33KV FEEDER NaN NaN
# 306                           ABULE TAYLOR 33KV FEEDER NaN NaN
# 307             EMERGENCY OUTAGE ON T2 100MVA ALIMOSHO NaN NaN

# %%
zones = {'IJU':[6.6712,3.3515], 'OKE':[6.6263,3.2835], 'AYANGBURIN':[6.619, 3.502],
         'OREGUN':[6.616146, 3.362653], 'EGBEDA':[6.5916, 3.2911], 'FAGBA':[6.657, 3.324],
         'PTC':[6.5920, 3.3435], 'AIT':[6.668, 3.263], 'ABULE': [6.590, 3.285], 'IGANDO':[6.546, 3.248],
         'ADIYAN':[6.69083,3.33972], 'AMUWO':[6.463,3.298], 'LASUNWON':[6.649, 3.514],
         'IJAIYE':[6.629, 3.338], 'IKOTUN':[6.554,3.269], 'OWUTU': [6.645, 3.479], 'IFAKO':[6.683, 3.294],
         'OBA':[6.611, 3.340], 'ODOGUNYAN':[6.673, 3.516], 'OKEIRA':[6.491, 3.370], 'OLAMBE':[6.694, 3.341],
         'AKUTE':[6.682, 3.356],'KETU':[6.598, 3.390],'MENDE':[6.572, 3.372], 'OJODU':[6.634, 3.356],
         'IGBOBI':[6.528, 3.374], 'ILUPEJU':[6.554, 3.356], 'MAGODO':[6.618, 3.400], 'DOPEMU':[6.613, 3.314],
         'OSHODI':[6.554, 3.337], 'ISOLO':[6.538, 3.323], 'ANIFOWOSHE':[6.598, 3.337], 'BARIGA':[6.539, 3.386],
         'OLATEJU':[6.535, 3.359], 'IDIMU':[6.584, 3.246], 'AGO':[6.508, 3.309], 'AYOBO':[6.606, 3.244],
         'OWORO':[6.544, 3.399], 'IKOSI':[6.600, 3.383], 'AJAO':[6.546, 3.326], 'IPAJA':[6.613, 3.266],
         'IJEDE':[6.571, 3.597], 'IGBOGBO':[6.585, 3.525], 'OKOTA':[6.500, 3.310],'GOWON-ESTATE':[6.604, 3.285],
         'OLOWORA':[6.635, 3.384], 'OGBA':[6.625, 3.344], 'IJEGUN': [6.517, 3.262], 'OGUDU':[6.574, 3.394],
         'ABORU':[6.636, 3.283], 'ORILE-AGEGE':[6.629, 3.311], 'EPE':[6.649, 3.713]
        }

# %%
#app = Nominatim(user_agent="project")
for index, row in df.iterrows():
    # Access row data
    undertaking = row['Undertaking']
    y = zones[undertaking][0]
    #y = location['lat']
    #x = location['lon']
    x = zones[undertaking][1]
    df.at[index, 'y'] = y
    df.at[index, 'x'] = x

# %%
# Calculate the bounding coordinate box
min_x = df['x'].min()
max_x = df['x'].max()
min_y = df['y'].min()
max_y = df['y'].max()

# Create a list to store the bounding coordinate box values
bbox = [min_x, max_x, min_y, max_y]

# Print the bounding coordinate box list
print("Bounding Coordinate Box List:")
print(bbox)
# Out:
# Bounding Coordinate Box List:
# [3.244, 3.713, 6.463, 6.694]

# %%
gdf = gpd.GeoDataFrame(df, crs='epsg:4326', geometry=gpd.points_from_xy(df.x, df.y))
gdf['Date'] = gdf['Date'].astype(str)
gdf = gdf.cx[bbox[0]:bbox[2], bbox[1]:bbox[3]]

# %%
gdf
# Out:
#          Branch        Date Undertaking  \
# 0       IKORODU  2024-04-04         EPE
# 1       SHOMOLU  2024-04-04      IGBOBI
# 2    ABULE-EGBA  2024-04-02         IJU
# 3       IKORODU  2024-04-02   ODOGUNYAN
# 4      AKOWONJO  2024-04-02      DOPEMU
# ..          ...         ...         ...
# 579  ABULE-EGBA  2021-11-04       FAGBA
# 580  ABULE-EGBA  2021-11-04       FAGBA
# 581     SHOMOLU  2021-10-24        KETU
# 582  ABULE-EGBA  2021-10-10       FAGBA
# 583  ABULE-EGBA  2021-10-10       FAGBA
#
#                                                  Fault  \
# 0                     AGBOWA 33KV FEEDER OUT ON FAULTS
# 1    PROLONGED OUTAGE ON 33-OWORONSHOKITCN-IGBOBI F...
# 2                         OUTAGE ON ISHAGA 11KV FEEDER
# 3    11-ODOGUNYANINJ-T1-AGODO IS OUT ON FAULT DUE T...
# 4              PROLONGED OUTAGE PEN CINEMA 11KV FEEDER
# ..                                                 ...
# 579                FAULT AFFECTING AGBE RD 11KV FEEDER
# 580                FAULT AFFECTING AGBE RD 11KV FEEDER
# 581                         FAULT ON  KETU 11KV FEEDER
# 582                     FAULT ON AGBE ROAD 11KV FEEDER
# 583                     FAULT ON AGBE ROAD 11KV FEEDER
#
#                                   Areas       y       x  \
# 0                    AGBOWA 33KV FEEDER  6.6490  3.7130
# 1       33-OWORONSHOKITCN-IGBOBI FEEDER  6.5280  3.3740
# 2                   11-IJUINJ-T2-ISHAGA  6.6712  3.3515
# 3              11-ODOGUNYANINJ-T1-AGODO  6.6730  3.5160
# 4             11-AGEGEINJ-T3-PEN CINEMA  6.6130  3.3140
# ..                                  ...     ...     ...
# 579                               FAGBA  6.6570  3.3240
# 580                               FAGBA  6.6570  3.3240
# 581      CUSTOMERS ON  KETU 11KV FEEDER  6.5980  3.3900
# 582  CUSTOMERS ON AGBE ROAD 11KV FEEDER  6.6570  3.3240
# 583  CUSTOMERS ON AGBE ROAD 11KV FEEDER  6.6570  3.3240
#
#                     geometry
# 0    POINT (3.71300 6.64900)
# 1    POINT (3.37400 6.52800)
# 2    POINT (3.35150 6.67120)
# 3    POINT (3.51600 6.67300)
# 4    POINT (3.31400 6.61300)
# ..                       ...
# 579  POINT (3.32400 6.65700)
# 580  POINT (3.32400 6.65700)
# 581  POINT (3.39000 6.59800)
# 582  POINT (3.32400 6.65700)
# 583  POINT (3.32400 6.65700)
#
# [584 rows x 8 columns]

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4073bdd8f17cf694d6db60de230a5111 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4073bdd8f17cf694d6db60de230a5111&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4073bdd8f17cf694d6db60de230a5111 = L.map(
#                 &quot;map_4073bdd8f17cf694d6db60de230a5111&quot;,
#                 {
#                     center: [6.5785, 3.4785000000000004],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4073bdd8f17cf694d6db60de230a5111);
#
#
#
#
#
#             var tile_layer_848bd213dbc786b4daf8caa02056d287 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4073bdd8f17cf694d6db60de230a5111);
#
#
#             map_4073bdd8f17cf694d6db60de230a5111.fitBounds(
#                 [[6.463, 3.244], [6.694, 3.713]],
#                 {}
#             );
#
#
#         function geo_json_44800ae6399a167f1a6a74ac11addfe5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_44800ae6399a167f1a6a74ac11addfe5_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_44800ae6399a167f1a6a74ac11addfe5_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_44800ae6399a167f1a6a74ac11addfe5_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_44800ae6399a167f1a6a74ac11addfe5_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_44800ae6399a167f1a6a74ac11addfe5.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_44800ae6399a167f1a6a74ac11addfe5_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_44800ae6399a167f1a6a74ac11addfe5 = L.geoJson(null, {
#                 onEachFeature: geo_json_44800ae6399a167f1a6a74ac11addfe5_onEachFeature,
#
#                 style: geo_json_44800ae6399a167f1a6a74ac11addfe5_styler,
#                 pointToLayer: geo_json_44800ae6399a167f1a6a74ac11addfe5_pointToLayer
#         });
#
#         function geo_json_44800ae6399a167f1a6a74ac11addfe5_add (data) {
#             geo_json_44800ae6399a167f1a6a74ac11addfe5
#                 .addData(data)
#                 .addTo(map_4073bdd8f17cf694d6db60de230a5111);
#         }
#             geo_json_44800ae6399a167f1a6a74ac11addfe5_add({&quot;bbox&quot;: [3.244, 6.463, 3.713, 6.694], &quot;features&quot;: [{&quot;bbox&quot;: [3.713, 6.649, 3.713, 6.649], &quot;geometry&quot;: {&quot;coordinates&quot;: [3.713, 6.649], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Areas&quot;: &quot;AGBOWA 33KV FEEDER&quot;, &quot;Branch&quot;: &quot;IKORODU&quot;, &quot;Date&quot;: &quot;2024-04-04&quot;, &quot;Fault&quot;: &quot;AGBOWA 33KV FEEDER OUT ON FAULTS&quot;, &quot;Undertaking&quot;: &quot;EPE&quot;, &quot;x&quot;: 3.713, &quot;y&quot;: 6.649}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [3.374, 6.528, 3.374, 6.528], &quot;geometry&quot;: {&quot;coordinates&quot;:

# %%
gdf['y'] = gdf['y'].astype(float)
gdf['x'] = gdf['x'].astype(float)

# %%
gdf.to_file('gdf.geojson', driver='GeoJSON')

# %%
gdf
# Out:
#          Branch        Date Undertaking  \
# 0    ABULE-EGBA  2024-03-01         IJU
# 1    ABULE-EGBA  2024-01-08         IJU
# 2    ABULE-EGBA  2024-01-08         IJU
# 3      AKOWONJO  2024-01-05         OKE
# 4    ABULE-EGBA  2023-12-23         IJU
# ..          ...         ...         ...
# 573  ABULE-EGBA  2021-10-10       FAGBA
# 574  ABULE-EGBA  2021-10-10       FAGBA
# 575  ABULE-EGBA  2021-10-04       FAGBA
# 576     SHOMOLU  2021-10-02       OWORO
# 577     SHOMOLU  2021-10-02       OWORO
#
#                                                  Fault  \
# 0    CNN NOTIFICATIONS TO CUSTOMERS ON 11-OBAWOLEIN...
# 1           CNN REQUEST TO CUSTOMERS OUT DUE TO FAULT.
# 2                           OUTAGE ON GALILEE 11KV FDR
# 3                PROLONG OUTAGE ON OKE ODO 11KV FEEDER
# 4                           OUTAGE ON GALILEE 11KV FDR
# ..                                                 ...
# 573                     FAULT ON AGBE ROAD 11KV FEEDER
# 574                     FAULT ON AGBE ROAD 11KV FEEDER
# 575  FAULT ON 11-IJAIYE OJOKOROINJ-T1-AGBADO 2-MAJE...
# 576                         FAULT ON OWORO IGBOBI 33KV
# 577                         FAULT ON OWORO IGBOBI 33KV
#
#                                                  Areas       y       x  \
# 0    CUSTOMERS ON 11-OBAWOLEINJ-T1-SHONUBI-CAJE 2 3...  6.6712  3.3515
# 1    11-AGEGEINJ-T1-IJU ROAD-1 OPA ARO CL HVDS – OP...  6.6712  3.3515
# 2                                         GALILEE 11KV  6.6712  3.3515
# 3                                              OKE ODO  6.6263  3.2835
# 4                                         GALILEE 11KV  6.6712  3.3515
# ..                                                 ...     ...     ...
# 573                 CUSTOMERS ON AGBE ROAD 11KV FEEDER  6.6570  3.3240
# 574                 CUSTOMERS ON AGBE ROAD 11KV FEEDER  6.6570  3.3240
# 575  CUSTOMERS ON 11-IJAIYE OJOKOROINJ-T1-AGBADO 2-...  6.6570  3.3240
# 576                     CUSTOMERS ON OWORO IGBOBI 33KV  6.5440  3.3990
# 577                     CUSTOMERS ON OWORO IGBOBI 33KV  6.5440  3.3990
#
#                     geometry
# 0    POINT (3.35150 6.67120)
# 1    POINT (3.35150 6.67120)
# 2    POINT (3.35150 6.67120)
# 3    POINT (3.28350 6.62630)
# 4    POINT (3.35150 6.67120)
# ..                       ...
# 573  POINT (3.32400 6.65700)
# 574  POINT (3.32400 6.65700)
# 575  POINT (3.32400 6.65700)
# 576  POINT (3.39900 6.54400)
# 577  POINT (3.39900 6.54400)
#
# [578 rows x 8 columns]

# %%
import folium
from folium.plugins import HeatMap

# Create a map centered at a location
m = folium.Map(location=[gdf['y'].mean(), gdf['x'].mean()], zoom_start=10)

# Convert the GeoDataFrame to a list of points
heat_data = [[point.xy[1][0], point.xy[0][0]] for point in gdf['geometry']]

# Add the HeatMap layer to the map
HeatMap(heat_data).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6f39128e1b4fb114eb9f0597d223985 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6f39128e1b4fb114eb9f0597d223985&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6f39128e1b4fb114eb9f0597d223985 = L.map(
#                 &quot;map_e6f39128e1b4fb114eb9f0597d223985&quot;,
#                 {
#                     center: [6.612669873287671, 3.342766734589041],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc379a55a0068141d34ae0511613e0f0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e6f39128e1b4fb114eb9f0597d223985);
#
#
#             var heat_map_5e0899a037a41863a0a7f4441bc42afa = L.heatLayer(
#                 [[6.649, 3.713], [6.528, 3.374], [6.6712, 3.3515], [6.673, 3.516], [6.613, 3.314], [6.657, 3.324], [6.463, 3.298], [6.463, 3.298], [6.618, 3.4], [6.6712, 3.3515], [6.6712, 3.3515], [6.6712, 3.3515], [6.6263, 3.2835], [6.6712, 3.3515], [6.619, 3.502], [6.616146, 3.362653], [6.5916, 3.2911], [6.657, 3.324], [6.657, 3.324], [6.592, 3.3435], [6.5916, 3.2911], [6.592, 3.3435], [6.668, 3.263], [6.59, 3.285], [6.546, 3.248], [6.69083, 3.33972], [6.616146, 3.362653], [6.463, 3.298], [6.649, 3.514], [6.616146, 3.362653], [6.629, 3.338], [6.629, 3.338], [6.554, 3.269], [6.645, 3.479], [6.645, 3.479], [6.683, 3.294], [6.611, 3.34], [6.673, 3.516], [6.6712, 3.3515], [6.6712, 3.3515], [6.59, 3.285], [6.491, 3.37], [6.645, 3.479], [6.694, 3.341], [6.611, 3.34], [6.682, 3.356], [6.598, 3.39], [6.572, 3.372], [6.694, 3.341], [6.592, 3.3435], [6.611, 3.34], [6.616146, 3.362653], [6.611, 3.34], [6.611, 3.34], [6.6712, 3.3515], [6.592, 3.3435], [6.634, 3.356], [6.592, 3.3435], [6.592, 3.3435], [6.673, 3.516], [6.619, 3.502], [6.59, 3.285], [6.619, 3.502], [6.528, 3.374], [6.528, 3.374], [6.554, 3.356], [6.592, 3.3435], [6.59, 3.285], [6.59, 3.285], [6.682, 3.356], [6.682, 3.356], [6.616146, 3.362653], [6.618, 3.4], [6.619, 3.502], [6.613, 3.314], [6.694, 3.341], [6.554, 3.337], [6.682, 3.356], [6.538, 3.323], [6.598, 3.337], [6.694, 3.341], [6.6712, 3.3515], [6.539, 3.386], [6.657, 3.324], [6.6712, 3.3515], [6.6712, 3.3515], [6.528, 3.374], [6.619, 3.502], [6.592, 3.3435], [6.694, 3.341], [6.6712, 3.3515], [6.6712, 3.3515], [6.6712, 3.3515], [6.535, 3.359], [6.649, 3.514], [6.592, 3.3435], [6.694, 3.341], [6.694, 3.341], [6.592, 3.3435], [6.619, 3.502], [6.592, 3.3435], [6.584, 3.246], [6.629, 3.338], [6.508, 3.309], [6.598, 3.39], [6.491, 3.37], [6.528, 3.374], [6.592, 3.3435], [6.682, 3.356], [6.649, 3.514], [6.649, 3.514], [6.554, 3.269], [6.554, 3.269], [6.694, 3.341], [6.657, 3.324], [6.606, 3.244], [6.616146, 3.362653], [6.544, 3.399], [6.584, 3.246], [6.528, 3.374], [6.634, 3.356], [6.618, 3.4], [6.6, 3.383], [6.592, 3.3435], [6.546, 3.326], [6.598, 3.39], [6.683, 3.294], [6.508, 3.309], [6.538, 3.323], [6.682, 3.356], [6.5916, 3.2911], [6.668, 3.263], [6.619, 3.502], [6.649, 3.514], [6.592, 3.3435], [6.616146, 3.362653], [6.538, 3.323], [6.598, 3.39], [6.508, 3.309], [6.528, 3.374], [6.535, 3.359], [6.6263, 3.2835], [6.694, 3.341], [6.6712, 3.3515], [6.6712, 3.3515], [6.6712, 3.3515], [6.554, 3.356], [6.657, 3.324], [6.554, 3.269], [6.619, 3.502], [6.682, 3.356], [6.554, 3.356], [6.491, 3.37], [6.539, 3.386], [6.592, 3.3435], [6.592, 3.3435], [6.544, 3.399], [6.6712, 3.3515], [6.598, 3.39], [6.5916, 3.2911], [6.528, 3.374], [6.544, 3.399], [6.657, 3.324], [6.554, 3.269], [6.554, 3.269], [6.606, 3.244], [6.592, 3.3435], [6.592, 3.3435], [6.613, 3.266], [6.508, 3.309], [6.571, 3.597], [6.611, 3.34], [6.6, 3.383], [6.463, 3.298], [6.546, 3.326], [6.571, 3.597], [6.592, 3.3435], [6.598, 3.39], [6.585, 3.525], [6.528, 3.374], [6.546, 3.248], [6.5916, 3.2911], [6.592, 3.3435], [6.598, 3.337], [6.598, 3.337], [6.616146, 3.362653], [6.5, 3.31], [6.491, 3.37], [6.592, 3.3435], [6.584, 3.246], [6.5916, 3.2911], [6.657, 3.324], [6.592, 3.3435], [6.6, 3.383], [6.546, 3.326], [6.604, 3.285], [6.539, 3.386], [6.619, 3.502], [6.508, 3.309], [6.613, 3.314], [6.683, 3.294], [6.592, 3.3435], [6.604, 3.285], [6.5916, 3.2911], [6.463, 3.298], [6.463, 3.298], [6.554, 3.269], [6.673, 3.516], [6.606, 3.244], [6.673, 3.516], [6.508, 3.309], [6.571, 3.597], [6.606, 3.244], [6.528, 3.374], [6.528, 3.374], [6.635, 3.384], [6.606, 3.244], [6.5916, 3.2911], [6.606, 3.244], [6.585, 3.525], [6.592, 3.3435], [6.694, 3.341], [6.463, 3.298], [6.618, 3.4], [6.546, 3.326], [6.546, 3.326], [6.546, 3.326], [6.546, 3.326], [6.554, 3.337], [6.592, 3.3435], [6.5916, 3.2911], [6.538, 3.323], [6.625, 3.344], [6.61

# %%
from folium import plugins
from folium.plugins import MarkerCluster
# Create a map centered at a location
m = folium.Map(location=[gdf['y'].mean(), gdf['x'].mean()], zoom_start=10)

# Create a marker cluster
marker_cluster = MarkerCluster().add_to(m)

# Add markers for each outage location
for idx, row in gdf.iterrows():
    folium.Marker([row['y'], row['x']], popup=row['Fault']).add_to(marker_cluster)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56e0faef82bbe18812c02116a42c81e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56e0faef82bbe18812c02116a42c81e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56e0faef82bbe18812c02116a42c81e0 = L.map(
#                 &quot;map_56e0faef82bbe18812c02116a42c81e0&quot;,
#                 {
#                     center: [6.612669873287671, 3.342766734589041],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_47dd7412f22713b591271016209169bd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_56e0faef82bbe18812c02116a42c81e0);
#
#
#             var marker_cluster_969c2883bb0e3374a0b62fac6be4150c = L.markerClusterGroup(
#                 {}
#             );
#             map_56e0faef82bbe18812c02116a42c81e0.addLayer(marker_cluster_969c2883bb0e3374a0b62fac6be4150c);
#
#
#             var marker_fdbb6c6a0b8710e33c141df60688b220 = L.marker(
#                 [6.649, 3.713],
#                 {}
#             ).addTo(marker_cluster_969c2883bb0e3374a0b62fac6be4150c);
#
#
#         var popup_a8c2613a92301a60df13c7874f0c7a23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21d081b69a8927684c767080600ad031 = $(`&lt;div id=&quot;html_21d081b69a8927684c767080600ad031&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AGBOWA 33KV FEEDER OUT ON FAULTS&lt;/div&gt;`)[0];
#                 popup_a8c2613a92301a60df13c7874f0c7a23.setContent(html_21d081b69a8927684c767080600ad031);
#
#
#
#         marker_fdbb6c6a0b8710e33c141df60688b220.bindPopup(popup_a8c2613a92301a60df13c7874f0c7a23)
#         ;
#
#
#
#
#             var marker_5f36709b6e3f01c5d241c9c074908c3c = L.marker(
#                 [6.528, 3.374],
#                 {}
#             ).addTo(marker_cluster_969c2883bb0e3374a0b62fac6be4150c);
#
#
#         var popup_1d727e84f58f570819aa6ea2b3a02eba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_065da675f301d3a44ae295111a5c51c8 = $(`&lt;div id=&quot;html_065da675f301d3a44ae295111a5c51c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PROLONGED OUTAGE ON 33-OWORONSHOKITCN-IGBOBI FEEDER&lt;/div&gt;`)[0];
#                 popup_1d727e84f58f570819aa6ea2b3a02eba.setContent(html_065da675f301d3a44ae295111a5c51c8);
#
#
#
#         marker_5f36709b6e3f01c5d241c9c074908c3c.bindPopup(popup_1d727e84f58f570819aa6ea2b3a02eba)
#         ;
#
#
#
#
#             var marker_7877524c55bfb18d01fd04ea3681182b = L.marker(
#                 [6.6712, 3.3515],
#                 {}
#             ).addTo(marker_cluster_969c2883bb0e3374a0b62fac6be4150c);
#
#
#         var popup_8fd3781e52a9d8dee0a43209ff97409d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a002e9527013c0e5c5b00ee176fd1d1c = $(`&lt;div id=&quot;html_a002e9527013c0e5c5b00ee176fd1d1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;OUTAGE ON ISHAGA 11KV FEEDER&lt;/div&gt;`)[0];
#                 popup_8fd3781e52a9d8dee0a43209ff97409d.setContent(html_a002e9527013c0e5c5b00ee176fd1d1c);
#
#
#
#         marker_7877524c55bfb18d01fd04ea3681182b.bindPopup(popup_8fd3781e52a9d8dee0a43209ff97409d)
#         ;
#
#
#
#
#             var marker_d230e908de724886d6178f54f0c2dc6a = L.marker(
#                 [6.673, 3.516],
#                 {}
#             ).addTo(marker_cluster_969c2883bb0e3374a0b62fac6be4150c);
#
#
#         var popup_c34c9c400f11f2d9fbe1851606fccbed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b77ee2a93785c2aab95ffab2c3036f16 = $(`&lt;div id=&quot;html_b77ee2a93785c2aab95ffab2c3036f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11-ODOGUNYANINJ-T1-AGODO IS OUT ON FAULT DUE TO ATTEMPTED VANDALISM AT THE FRIST UPRISER CABLE&lt;/div&gt;`)[0];
#                 popup_c34c9c400f11f2d9fbe1851606fccbed.setContent(html_b77ee2a93785c2aab95ffab2c3036f16);
#
#
#
#         marker_d230e908de724886d6178f54f0c2dc6a.bindPopup(popup_c34c9c400f11f2d9fbe1851606fccbed)
#         ;
#
#
#
#
#             var marker_0caeed8d8f3af5226426f3

# %%
# Create a map centered at a location
m = folium.Map(location=[gdf['y'].mean(), gdf['x'].mean()], zoom_start=10)

# Create a MarkerCluster to group outage incidents by undertaking
marker_cluster = MarkerCluster().add_to(m)

# Get the total count of outages for each undertaking
undertaking_outage_counts = gdf['Undertaking'].value_counts().to_dict()

# Iterate through each row in the DataFrame
for index, row in gdf.iterrows():
    # Get the total count of outages for the undertaking of the current row
    total_outages = undertaking_outage_counts[row['Undertaking']]
    
    # Determine the color based on the total count of outages
    if total_outages >= 10:
        color = 'red'
    elif total_outages >= 5:
        color = 'orange'
    else:
        color = 'green'
    
    # Create a popup that includes the fault and the date
    popup = f"Fault: {row['Fault']}<br>Date: {row['Date']}"
    
    # Create a marker for each outage incident
    folium.Marker([row['y'], row['x']], popup=popup, icon=folium.Icon(color=color)).add_to(marker_cluster)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b131705495c878068e65baefb6c61763 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b131705495c878068e65baefb6c61763&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b131705495c878068e65baefb6c61763 = L.map(
#                 &quot;map_b131705495c878068e65baefb6c61763&quot;,
#                 {
#                     center: [6.612669873287671, 3.342766734589041],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4711fcd6c072ad2ced79f8680a4ee446 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b131705495c878068e65baefb6c61763);
#
#
#             var marker_cluster_62a8e81805eec3a5b01ba79fa6980cdf = L.markerClusterGroup(
#                 {}
#             );
#             map_b131705495c878068e65baefb6c61763.addLayer(marker_cluster_62a8e81805eec3a5b01ba79fa6980cdf);
#
#
#             var marker_36d5c2a2acfaed50f174a150c5ee0817 = L.marker(
#                 [6.649, 3.713],
#                 {}
#             ).addTo(marker_cluster_62a8e81805eec3a5b01ba79fa6980cdf);
#
#
#             var icon_81743a95f3465f1c8bde2c3323228c6a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_36d5c2a2acfaed50f174a150c5ee0817.setIcon(icon_81743a95f3465f1c8bde2c3323228c6a);
#
#
#         var popup_8612d90acda60c9a69436a3615f887ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd59343837f95a58837a04f00345e612 = $(`&lt;div id=&quot;html_fd59343837f95a58837a04f00345e612&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fault: AGBOWA 33KV FEEDER OUT ON FAULTS&lt;br&gt;Date: 2024-04-04&lt;/div&gt;`)[0];
#                 popup_8612d90acda60c9a69436a3615f887ad.setContent(html_fd59343837f95a58837a04f00345e612);
#
#
#
#         marker_36d5c2a2acfaed50f174a150c5ee0817.bindPopup(popup_8612d90acda60c9a69436a3615f887ad)
#         ;
#
#
#
#
#             var marker_b390fa26626028ef3b5d5a03f6594887 = L.marker(
#                 [6.528, 3.374],
#                 {}
#             ).addTo(marker_cluster_62a8e81805eec3a5b01ba79fa6980cdf);
#
#
#             var icon_745dd3aac5d60a5b5b2053a2f6d683e9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b390fa26626028ef3b5d5a03f6594887.setIcon(icon_745dd3aac5d60a5b5b2053a2f6d683e9);
#
#
#         var popup_43bb99e627e5d8ea1b285bfbc3f5ff85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e7b827ce71b51f06396060873f0d846 = $(`&lt;div id=&quot;html_4e7b827ce71b51f06396060873f0d846&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fault: PROLONGED OUTAGE ON 33-OWORONSHOKITCN-IGBOBI FEEDER&lt;br&gt;Date: 2024-04-04&lt;/div&gt;`)[0];
#                 popup_43bb99e627e5d8ea1b285bfbc3f5ff85.setContent(html_4e7b827ce71b51f06396060873f0d846);
#
#
#
#         marker_b390fa26626028ef3b5d5a03f6594887.bindPopup(popup_43bb99e627e5d8ea1b285bfbc3f5ff85)
#         ;
#
#
#
#
#             var marker_bc0ebc6ec4cb985d7995896f4827591e = L.marker(
#                 [6.6712, 3.3515],
#                 {}
#             ).addTo(marker_cluster_62a8e81805eec3a5b01ba79fa6980cdf);
#
#
#             var icon_d02a527b7cb4948ab729746e708f7b2f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bc0ebc6ec4cb985d7995896f4827591e.setIcon(icon_d02a527b7cb4948ab729746e708f7b2f);
#
#
#         var popup_1977bbd457b4d03652eb77ca02058905 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %%
m.save("footprint.html")

# %%
# Remove rows with NaN values
gdf_cleaned = gdf.dropna()

# Or replace NaN values with a specific value
gdf_filled = gdf.fillna(0)  # Replace NaN with 0

# %%
import folium
from folium import Choropleth

# Create a map centered at a location
m = folium.Map(location=[gdf['y'].mean(), gdf['x'].mean()], zoom_start=10)

# Create a choropleth map based on outage data
choropleth = Choropleth(
    geo_data='path_to_geojson_file.geojson',  # GeoJSON file containing polygon boundaries
    data=gdf,  # DataFrame containing outage data
    columns=['Branch', 'Fault'],  # Columns for mapping
    key_on='feature.properties.Branch',  # Key in GeoJSON for mapping
    fill_color='YlOrRd',  # Color scale
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Outage Faults'
).add_to(m)

# Display the map
m
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       5 m = folium.Map(location=[gdf['y'].mean(), gdf['x'].mean()], zoom_start=10)
#       7 # Create a choropleth map based on outage data
# ----> 8 choropleth = Choropleth(
#       9     geo_data='path_to_geojson_file.geojson',  # GeoJSON file containing polygon boundaries
#      10     data=gdf,  # DataFrame containing outage data
#      11     columns=['Branch', 'Fault'],  # Columns for mapping
#      12     key_on='feature.properties.Branch',  # Key in GeoJSON for mapping
#      13     fill_color='YlOrRd',  # Color scale
#      14     fill_opacity=0.7,
#      15     line_opacity=0.2,
#      16     legend_name='Outage Faults'
#      17 ).add_to(m)
#      19 # Display the map
#      20 m
#
# File ~/miniforge3/envs/source-api/lib/python3.8/site-packages/folium/features.py:1487, in Choropleth.__init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, use_jenks, **kwargs)
#    1485 if color_data is not None and key_on is not None:
#    1486     real_values = np.array(list(color_data.values()))
# -> 1487     real_values = real_values[~np.isnan(real_values)]
#    1488     if use_jenks:
#    1489         from jenkspy import jenks_breaks
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
nan_values = gdf.isna().sum()
print(nan_values)
# Out:
# Branch         0
# Date           0
# Undertaking    0
# Fault          0
# Areas          0
# y              0
# x              0
# geometry       0
# dtype: int64

# %%
# Create a map centered at a location
m = folium.Map(location=[gdf['y'].mean(), gdf['x'].mean()], zoom_start=10)

# Create a MarkerCluster to group outage incidents by branch
marker_cluster = MarkerCluster().add_to(m)

# Iterate through each row in the DataFrame
for index, row in gdf.iterrows():
    # Define the color based on the number of outage incidents (you can modify this logic)
    if row['Fault'] == 'High':
        color = 'red'
    elif row['Fault'] == 'Medium':
        color = 'orange'
    else:
        color = 'green'
    
    # Create a marker for each outage incident
    folium.Marker([row['y'], row['x']], popup=row['Fault'], icon=folium.Icon(color=color)).add_to(marker_cluster)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_129a9eb13f6ccc27daf0765e94ff9018 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_129a9eb13f6ccc27daf0765e94ff9018&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_129a9eb13f6ccc27daf0765e94ff9018 = L.map(
#                 &quot;map_129a9eb13f6ccc27daf0765e94ff9018&quot;,
#                 {
#                     center: [6.612669873287671, 3.342766734589041],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f255885ae4484d5e0f05e73c36300fc8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_129a9eb13f6ccc27daf0765e94ff9018);
#
#
#             var marker_cluster_21b41c68957450a6807f9831e2625146 = L.markerClusterGroup(
#                 {}
#             );
#             map_129a9eb13f6ccc27daf0765e94ff9018.addLayer(marker_cluster_21b41c68957450a6807f9831e2625146);
#
#
#             var marker_9ba8ec6776daee59de8f00a16ee42abf = L.marker(
#                 [6.649, 3.713],
#                 {}
#             ).addTo(marker_cluster_21b41c68957450a6807f9831e2625146);
#
#
#             var icon_da0c7378033096f3431450234ea9708e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9ba8ec6776daee59de8f00a16ee42abf.setIcon(icon_da0c7378033096f3431450234ea9708e);
#
#
#         var popup_04a8815a1143e0fd60185420fd885d23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eae301f470b87a35b615c7f1d1e7b2a0 = $(`&lt;div id=&quot;html_eae301f470b87a35b615c7f1d1e7b2a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AGBOWA 33KV FEEDER OUT ON FAULTS&lt;/div&gt;`)[0];
#                 popup_04a8815a1143e0fd60185420fd885d23.setContent(html_eae301f470b87a35b615c7f1d1e7b2a0);
#
#
#
#         marker_9ba8ec6776daee59de8f00a16ee42abf.bindPopup(popup_04a8815a1143e0fd60185420fd885d23)
#         ;
#
#
#
#
#             var marker_5ca9b0f5434886b166428f22f8c210e1 = L.marker(
#                 [6.528, 3.374],
#                 {}
#             ).addTo(marker_cluster_21b41c68957450a6807f9831e2625146);
#
#
#             var icon_13b2009683ed83d82911ad7f11fba417 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5ca9b0f5434886b166428f22f8c210e1.setIcon(icon_13b2009683ed83d82911ad7f11fba417);
#
#
#         var popup_872f73dc20225c44f4683d676aebede3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e22eac17989cdf93e391be6eac3d3b3 = $(`&lt;div id=&quot;html_8e22eac17989cdf93e391be6eac3d3b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PROLONGED OUTAGE ON 33-OWORONSHOKITCN-IGBOBI FEEDER&lt;/div&gt;`)[0];
#                 popup_872f73dc20225c44f4683d676aebede3.setContent(html_8e22eac17989cdf93e391be6eac3d3b3);
#
#
#
#         marker_5ca9b0f5434886b166428f22f8c210e1.bindPopup(popup_872f73dc20225c44f4683d676aebede3)
#         ;
#
#
#
#
#             var marker_92c155a559795fef0ba499d842bcb9ea = L.marker(
#                 [6.6712, 3.3515],
#                 {}
#             ).addTo(marker_cluster_21b41c68957450a6807f9831e2625146);
#
#
#             var icon_169b795b372018e2f195e611d2fd1140 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_92c155a559795fef0ba499d842bcb9ea.setIcon(icon_169b795b372018e2f195e611d2fd1140);
#
#
#         var popup_ee991755a5343d18b24e8e549140eb83 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b4112abd283ce6a2f0709291e4e9a00 = $(`

# %%
# Perfect, right now

import folium
from folium.plugins import MarkerCluster

# Create a map centered at a location
m = folium.Map(location=[gdf['y'].mean(), gdf['x'].mean()], zoom_start=10)

# Create a marker cluster
marker_cluster = MarkerCluster().add_to(m)

# Add markers for each outage location with popup clusters
for idx, row in gdf.iterrows():
    folium.Marker([row['y'], row['x']], popup=row['Fault']).add_to(marker_cluster)

# Display the map
m

# %%
# This is so perfect

import folium
from folium.plugins import TimestampedGeoJson

# Convert the DataFrame to GeoJSON with timestamp
features = [
    {
        'type': 'Feature',
        'geometry': {
            'type': 'Point',
            'coordinates': [row['x'], row['y']]
        },
        'properties': {
            'time': str(row['Date']),
            'popup': row['Fault']
        }
    }
    for idx, row in gdf.iterrows()
]

# Create a map centered at a location
m = folium.Map(location=[gdf['y'].mean(), gdf['x'].mean()], zoom_start=10)

# Add the TimestampedGeoJson layer for time-series animation
TimestampedGeoJson(
    {'type': 'FeatureCollection', 'features': features},
    period='P1D',  # Time period
    add_last_point=True,
    auto_play=True
).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9dc81585958b7180db42ed51d13b886a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/2.0.0/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9dc81585958b7180db42ed51d13b886a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9dc81585958b7180db42ed51d13b886a = L.map(
#                 &quot;map_9dc81585958b7180db42ed51d13b886a&quot;,
#                 {
#                     center: [6.612669873287671, 3.342766734589041],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f4786729905449394c79837e2f1742d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9dc81585958b7180db42ed51d13b886a);
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format(&quot;YYYY-MM-DD HH:mm:ss&quot;);
#                 }
#             });
#             map_9dc81585958b7180db42ed51d13b886a.timeDimension = L.timeDimension(
#                 {
#                     period: &quot;P1D&quot;,
#                 }
#             );
#             var timeDimensionControl = new L.Control.TimeDimensionCustom(
#                 {&quot;autoPlay&quot;: true, &quot;loopButton&quot;: false, &quot;maxSpeed&quot;: 10, &quot;minSpeed&quot;: 0.1, &quot;playerOptions&quot;: {&quot;loop&quot;: true, &quot;startOver&quot;: true, &quot;transitionTime&quot;: 200}, &quot;position&quot;: &quot;bottomleft&quot;, &quot;speedSlider&quot;: true, &quot;timeSliderDragUpdate&quot;: false}
#             );
#             map_9dc81585958b7180db42ed51d13b886a.addControl(this.timeDimensionControl);
#
#             var geoJsonLayer = L.geoJson({&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [3.713, 6.649]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2024-04-04&quot;, &quot;popup&quot;: &quot;AGBOWA 33KV FEEDER OUT ON FAULTS&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [3.374, 6.528]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2024-04-04&quot;, &quot;popup&quot;: &quot;PROLONGED OUTAGE ON 33-OWORONSHOKITCN-IGBOBI FEEDER&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [3.3515, 6.6712]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2024-04-02&quot;, &quot;popup&quot;: &quot;OUTAGE ON ISHAGA 11KV FEEDER&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [3.516, 6.673]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2024-04-02&quot;, &quot;popup&quot;: &quot;11-ODOGUNYANINJ-T1-AGODO IS OUT ON FAULT DUE TO ATTEMPTED VANDALISM AT THE FRIST UPRISER CABLE&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [3.314, 6.613]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2024-04-02&quot;, &quot;popup&quot;: &quot;PROLONGED OUTAGE PEN CINEMA 11KV FEEDER&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [3.324, 6.657]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2024-03-28&quot;, &quot;popup&quot;: &quot;REQUEST FOR CNN&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [3.298, 6.463]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2024-03-18&quot;, &quot;popup&quot;: &quot;OUTAGE ON AGO LINE 2.&quot
